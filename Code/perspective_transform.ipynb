# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2 
import numpy as np
import pickle
import imageio.v2 as imageio

from helpers import show_images, save_image, scale_abs
from birdseye import BirdsEye

# %%
calibration_data = pickle.load(open("calibration_data.p", "rb" ))

matrix = calibration_data['camera_matrix']
dist_coef = calibration_data['distortion_coefficient']

source_points = [(580, 460), (205, 720), (1110, 720), (703, 460)]
dest_points = [(320, 0), (320, 720), (960, 720), (960, 0)]

birdsEye = BirdsEye(source_points, dest_points, matrix, dist_coef)

# %%
raw1= imageio.imread("test_images/straight_lines1.jpg")
raw2 = imageio.imread("test_images/straight_lines2.jpg")

# %%
temp = birdsEye.undistort(raw1, show_dotted = True)

# %%
temp = birdsEye.sky_view(raw1, show_dotted = True)

# %%
temp = birdsEye.undistort(raw2, show_dotted = True)

# %%
temp = birdsEye.sky_view(raw2, show_dotted = True)

# %%
raw = imageio.imread("test_images/special_test1.jpg")
temp = birdsEye.undistort(raw, show_dotted = True)

# %%
temp = birdsEye.sky_view(raw, show_dotted = True)

# %%
save_image(birdsEye.sky_view(raw1), "birdseye-straight", 1)
save_image(birdsEye.sky_view(raw2), "birdseye-straight", 2)
save_image(birdsEye.sky_view(raw), "birdseye-special-test", 1)

for i in range(1, 7):
  temp = imageio.imread("test_images/test" + str(i) + ".jpg")
  save_image(birdsEye.sky_view(temp), "birdseye-test", i)
  save_image(birdsEye.undistort(temp), "undistort-test", i)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[25], line 3
#       1 save_image(birdsEye.sky_view(raw1), "birdseye-straight", 1)
#       2 save_image(birdsEye.sky_view(raw2), "birdseye-straight", 2)
# ----> 3 save_image(birdsEye.sky_view(raw), "birdseye-special-test", 1)
#       5 for i in range(1, 7):
#       6   temp = imageio.imread("test_images/test" + str(i) + ".jpg")
#
# File D:\LECTs\파이썬_빅데이터_DB_딥러닝\Jupyter\lane_detection\advanced-lane-detection-master\helpers.py:20, in save_image(img, name, i)
#      18 def save_image(img, name, i):
#      19   path =  "output_images/" + name + str(i) + ".jpg"
# ---> 20   imsave(path, img)
#
# File ~\anaconda3\lib\site-packages\imageio\v2.py:264, in imwrite(uri, im, format, **kwargs)
#     262 imopen_args["legacy_mode"] = True
#     263 with imopen(uri, "wi", **imopen_args) as file:
# --> 264     return file.write(im, **kwargs)
#
# File ~\anaconda3\lib\site-packages\imageio\core\legacy_plugin_wrapper.py:253, in LegacyPlugin.write(self, ndimage, is_batch, metadata, **kwargs)
#     246         if not np.issubdtype(image.dtype, np.number) and not np.issubdtype(
#     247             image.dtype, bool
#     248         ):
#     249             raise ValueError(
#     250                 f"All images have to be numeric, and not `{image.dtype}`."
#     251             )
# --> 253         writer.append_data(image, metadata)
#     255 return writer.request.get_result()
#
# File ~\anaconda3\lib\site-packages\imageio\core\format.py:590, in Format.Writer.append_data(self, im, meta)
#     588 im = asarray(im)
#     589 # Call
# --> 590 return self._append_data(im, total_meta)
#
# File ~\anaconda3\lib\site-packages\imageio\plugins\pillow_legacy.py:533, in JPEGFormat.Writer._append_data(self, im, meta)
#     531 def _append_data(self, im, meta):
#     532     if im.ndim == 3 and im.shape[-1] == 4:
# --> 533         raise IOError("JPEG does not support alpha channel.")
#     534     im = image_as_uint(im, bitdepth=8)
#     535     PillowFormat.Writer._append_data(self, im, meta)
#
# OSError: JPEG does not support alpha channel.
